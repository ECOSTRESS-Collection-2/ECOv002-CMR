# %%
from ECOv002_CMR import ECOSTRESS_CMR_search

# %%
tile = "11SPS"
start_date = "2024-10-10"
end_date = "2024-11-11"

# %%
L2T_LSTE_df = ECOSTRESS_CMR_search("L2T_LSTE", tile, start_date, end_date)
L2T_LSTE_df
# Out:
#       product     variable  orbit  scene   tile             type  \
# 0    L2T_LSTE        water  35510      5  11SPS     GeoTIFF Data
# 1    L2T_LSTE        cloud  35510      5  11SPS     GeoTIFF Data
# 2    L2T_LSTE  view_zenith  35510      5  11SPS     GeoTIFF Data
# 3    L2T_LSTE       height  35510      5  11SPS     GeoTIFF Data
# 4    L2T_LSTE           QC  35510      5  11SPS     GeoTIFF Data
# ..        ...          ...    ...    ...    ...              ...
# 445  L2T_LSTE       height  35922      6  11SPS  GeoJPEG Preview
# 446  L2T_LSTE           QC  35922      6  11SPS  GeoJPEG Preview
# 447  L2T_LSTE          LST  35922      6  11SPS  GeoJPEG Preview
# 448  L2T_LSTE      LST_err  35922      6  11SPS  GeoJPEG Preview
# 449  L2T_LSTE       EmisWB  35922      6  11SPS  GeoJPEG Preview
#
#                                                granule  \
# 0    ECOv002_L2T_LSTE_35510_005_11SPS_20241010T1516...
# 1    ECOv002_L2T_LSTE_35510_005_11SPS_20241010T1516...
# ...

# %%
L2T_STARS_df = ECOSTRESS_CMR_search("L2T_STARS", tile, start_date, end_date)
L2T_STARS_df
